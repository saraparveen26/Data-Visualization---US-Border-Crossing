# %%
# Import dependencies
import pandas as pd

# Store file path
csv_path="Resources/Border_Crossing_Entry_Data.csv"

# Read the csv file
data_df = pd.read_csv(csv_path)
data_df
# Out:
#             Port Name         State  Port Code            Border  \
# 0       Calexico East    California       2507  US-Mexico Border
# 1           Van Buren         Maine        108  US-Canada Border
# 2           Otay Mesa    California       2506  US-Mexico Border
# 3             Nogales       Arizona       2604  US-Mexico Border
# 4         Trout River      New York        715  US-Canada Border
# ...               ...           ...        ...               ...
# 346728         Norton       Vermont        211  US-Canada Border
# 346729       Columbus    New Mexico       2406  US-Mexico Border
# 346730       Hansboro  North Dakota       3415  US-Canada Border
# 346731  Calexico East    California       2507  US-Mexico Border
# 346732       Presidio         Texas       2403  US-Mexico Border
#
#                           Date                      Measure  Value  \
# 0       03/01/2019 12:00:00 AM                       Trucks  34447
# ...

# %%
# List the colums in the dataset
data_df.columns
# Out:
# Index(['Port Name', 'State', 'Port Code', 'Border', 'Date', 'Measure', 'Value',
#        'Location'],
#       dtype='object')

# %%
# Reduce the dataset to the columns needed
reduced_df=data_df[['State', 'Border', 'Date', 'Measure', 'Value']]
reduced_df
# Out:
#                State            Border                    Date  \
# 0         California  US-Mexico Border  03/01/2019 12:00:00 AM
# 1              Maine  US-Canada Border  03/01/2019 12:00:00 AM
# 2         California  US-Mexico Border  03/01/2019 12:00:00 AM
# 3            Arizona  US-Mexico Border  03/01/2019 12:00:00 AM
# 4           New York  US-Canada Border  03/01/2019 12:00:00 AM
# ...              ...               ...                     ...
# 346728       Vermont  US-Canada Border  01/01/1996 12:00:00 AM
# 346729    New Mexico  US-Mexico Border  01/01/1996 12:00:00 AM
# 346730  North Dakota  US-Canada Border  01/01/1996 12:00:00 AM
# 346731    California  US-Mexico Border  01/01/1996 12:00:00 AM
# 346732         Texas  US-Mexico Border  01/01/1996 12:00:00 AM
#
#                             Measure  Value
# 0                            Trucks  34447
# 1              Rail Containers Full    428
# 2                            Trucks  81217
# ...

# %%
reduced_df.dtypes
# Out:
# State      object
# Border     object
# Date       object
# Measure    object
# Value       int64
# dtype: object

# %%
reduced_df["State"].value_counts()
# Out:
# North Dakota    57071
# Washington      44677
# Montana         38154
# Maine           38136
# Texas           35754
# Minnesota       23135
# New York        20697
# Arizona         19252
# California      19102
# Vermont         16247
# Alaska          11529
# Michigan         9985
# Idaho            6551
# New Mexico       6438
# Ohio                5
# Name: State, dtype: int64

# %%
reduced_df["Measure"].value_counts()
# Out:
# Personal Vehicles              30219
# Personal Vehicle Passengers    30196
# Trucks                         29856
# Truck Containers Empty         29757
# Truck Containers Full          29694
# Buses                          28822
# Bus Passengers                 28820
# Pedestrians                    28697
# Trains                         27708
# Rail Containers Empty          27684
# Rail Containers Full           27657
# Train Passengers               27623
# Name: Measure, dtype: int64

# %%
# Split the Date column
reduced1_df = reduced_df.copy()
reduced1_df[['Jour', 'Time', 'AM/PM']] = reduced1_df['Date'].str.split(" ", expand = True)
reduced1_df
# Out:
#                State            Border                    Date  \
# 0         California  US-Mexico Border  03/01/2019 12:00:00 AM
# 1              Maine  US-Canada Border  03/01/2019 12:00:00 AM
# 2         California  US-Mexico Border  03/01/2019 12:00:00 AM
# 3            Arizona  US-Mexico Border  03/01/2019 12:00:00 AM
# 4           New York  US-Canada Border  03/01/2019 12:00:00 AM
# ...              ...               ...                     ...
# 346728       Vermont  US-Canada Border  01/01/1996 12:00:00 AM
# 346729    New Mexico  US-Mexico Border  01/01/1996 12:00:00 AM
# 346730  North Dakota  US-Canada Border  01/01/1996 12:00:00 AM
# 346731    California  US-Mexico Border  01/01/1996 12:00:00 AM
# 346732         Texas  US-Mexico Border  01/01/1996 12:00:00 AM
#
#                             Measure  Value        Jour      Time AM/PM
# 0                            Trucks  34447  03/01/2019  12:00:00    AM
# ...

# %%
# Reduce the dataset to the columns needed
reduced2_df=reduced1_df[['State', 'Border', 'Measure', 'Value', 'Jour']]
reduced2_df
# Out:
#                State            Border                      Measure  Value  \
# 0         California  US-Mexico Border                       Trucks  34447
# 1              Maine  US-Canada Border         Rail Containers Full    428
# 2         California  US-Mexico Border                       Trucks  81217
# 3            Arizona  US-Mexico Border                       Trains     62
# 4           New York  US-Canada Border  Personal Vehicle Passengers  16377
# ...              ...               ...                          ...    ...
# 346728       Vermont  US-Canada Border  Personal Vehicle Passengers   9119
# 346729    New Mexico  US-Mexico Border            Personal Vehicles  29486
# 346730  North Dakota  US-Canada Border         Rail Containers Full      0
# 346731    California  US-Mexico Border                        Buses      0
# 346732         Texas  US-Mexico Border                       Trucks    347
#
#               Jour
# 0       03/01/2019
# 1       03/01/2019
# ...

# %%
# Split the Jour column
reduced3_df = reduced2_df.copy()
reduced3_df[['Month', 'Day', 'Year']] = reduced3_df['Jour'].str.split("/", expand = True)
reduced3_df
# Out:
#                State            Border                      Measure  Value  \
# 0         California  US-Mexico Border                       Trucks  34447
# 1              Maine  US-Canada Border         Rail Containers Full    428
# 2         California  US-Mexico Border                       Trucks  81217
# 3            Arizona  US-Mexico Border                       Trains     62
# 4           New York  US-Canada Border  Personal Vehicle Passengers  16377
# ...              ...               ...                          ...    ...
# 346728       Vermont  US-Canada Border  Personal Vehicle Passengers   9119
# 346729    New Mexico  US-Mexico Border            Personal Vehicles  29486
# 346730  North Dakota  US-Canada Border         Rail Containers Full      0
# 346731    California  US-Mexico Border                        Buses      0
# 346732         Texas  US-Mexico Border                       Trucks    347
#
#               Jour Month Day  Year
# ...

# %%
# Reduce the dataset to the columns needed
reduced3_df=reduced3_df[['State', 'Border', 'Measure', 'Value', 'Month', 'Year']]
reduced3_df
# Out:
#                State            Border                      Measure  Value  \
# 0         California  US-Mexico Border                       Trucks  34447
# 1              Maine  US-Canada Border         Rail Containers Full    428
# 2         California  US-Mexico Border                       Trucks  81217
# 3            Arizona  US-Mexico Border                       Trains     62
# 4           New York  US-Canada Border  Personal Vehicle Passengers  16377
# ...              ...               ...                          ...    ...
# 346728       Vermont  US-Canada Border  Personal Vehicle Passengers   9119
# 346729    New Mexico  US-Mexico Border            Personal Vehicles  29486
# 346730  North Dakota  US-Canada Border         Rail Containers Full      0
# 346731    California  US-Mexico Border                        Buses      0
# 346732         Texas  US-Mexico Border                       Trucks    347
#
#        Month  Year
# 0         03  2019
# 1         03  2019
# ...

# %%
# reduced4_df = reduced3_df.loc[(reduced3_df["Year"] == "2009") | 
#                               (reduced3_df["Year"] == "2010")]
# reduced4_df

# %%
years_to_analyze=['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018']
Years = []

for index, row in reduced3_df.iterrows():
    for year in years_to_analyze:
        if row["Year"] == year:
            Years.append(row)

Years
# Out:
# [State                 Maine
#  Border     US-Canada Border
#  Measure              Trucks
#  Value                  1204
#  Month                    12
#  Year                   2018
#  Name: 2364, dtype: object,
#  State          North Dakota
#  Border     US-Canada Border
#  Measure              Trucks
#  Value                   170
#  Month                    12
#  Year                   2018
#  Name: 2365, dtype: object,
#  State               Arizona
#  Border     US-Mexico Border
#  Measure               Buses
#  Value                   210
#  Month                    12
#  Year                   2018
#  Name: 2366, dtype: object,
#  State                 Texas
#  Border     US-Mexico Border
#  Measure      Bus Passengers
#  Value                   238
#  Month                    12
#  Year                   2018
#  Name: 2367, dtype: object,
#  State                       Washington
#  Border                US-Canada Border
#  Measure    Personal Vehicle Passengers
# ...

# %%
new_df = pd.DataFrame(Years)
new_df
# Out:
#                State            Border                      Measure  Value  \
# 2364           Maine  US-Canada Border                       Trucks   1204
# 2365    North Dakota  US-Canada Border                       Trucks    170
# 2366         Arizona  US-Mexico Border                        Buses    210
# 2367           Texas  US-Mexico Border               Bus Passengers    238
# 2368      Washington  US-Canada Border  Personal Vehicle Passengers   5350
# ...              ...               ...                          ...    ...
# 146964  North Dakota  US-Canada Border             Train Passengers      0
# 146965         Texas  US-Mexico Border                        Buses      7
# 146966    Washington  US-Canada Border        Truck Containers Full      0
# 146967      Michigan  US-Canada Border                  Pedestrians      0
# 146968    Washington  US-Canada Border         Rail Containers Full      0
#
#        Month  Year
# 2364      12  2018
# 2365      12  2018
# ...

# %%
new_df['Month'] = new_df['Month'].replace(['12'], 'Dec')
new_df
# Out:
#                State            Border                      Measure  Value  \
# 2364           Maine  US-Canada Border                       Trucks   1204
# 2365    North Dakota  US-Canada Border                       Trucks    170
# 2366         Arizona  US-Mexico Border                        Buses    210
# 2367           Texas  US-Mexico Border               Bus Passengers    238
# 2368      Washington  US-Canada Border  Personal Vehicle Passengers   5350
# ...              ...               ...                          ...    ...
# 146964  North Dakota  US-Canada Border             Train Passengers      0
# 146965         Texas  US-Mexico Border                        Buses      7
# 146966    Washington  US-Canada Border        Truck Containers Full      0
# 146967      Michigan  US-Canada Border                  Pedestrians      0
# 146968    Washington  US-Canada Border         Rail Containers Full      0
#
#        Month  Year
# 2364     Dec  2018
# 2365     Dec  2018
# ...
